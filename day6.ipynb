# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('Pittsburgh bridges.csv')

# %%
data = data.replace(data[data == '?'],np.nan)
data= data.dropna()

# %%
data
# Out:
#     IDENTIF RIVER LOCATION  ERECTED   PURPOSE LENGTH LANES CLEAR-G   T-OR-D  \
# 1        E2     A       25     1819   HIGHWAY   1037     2       N  THROUGH
# 3        E5     A       29     1837   HIGHWAY   1000     2       N  THROUGH
# 5        E7     A       27     1840   HIGHWAY    990     2       N  THROUGH
# 6        E8     A       28     1844  AQUEDUCT   1000     1       N  THROUGH
# 7        E9     M        3     1846   HIGHWAY   1500     2       N  THROUGH
# ..      ...   ...      ...      ...       ...    ...   ...     ...      ...
# 100     E86     A       33     1961   HIGHWAY    980     4       G     DECK
# 101     E85     M        9     1962   HIGHWAY   2213     4       G     DECK
# 102     E84     A       24     1969   HIGHWAY    870     6       G  THROUGH
# 103     E91     O       44     1975   HIGHWAY   3756     6       G  THROUGH
# 104     E90     M        7     1978   HIGHWAY    950     6       G  THROUGH
#
#     MATERIAL    SPAN REL-L    TYPE
# ...

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
data['RIVER'] = label_encoder.fit_transform(data['RIVER'])

# %%
data['PURPOSE'] = label_encoder.fit_transform(data['PURPOSE'])

# %%
data['CLEAR-G']=label_encoder.fit_transform(data['CLEAR-G'])

# %%
data['T-OR-D'] = label_encoder.fit_transform(data['T-OR-D'])

# %%
data['MATERIAL'] = label_encoder.fit_transform(data['MATERIAL'])

# %%
data['SPAN'] = label_encoder.fit_transform(data['SPAN'])

# %%
data['REL-L']= label_encoder.fit_transform(data['REL-L'])

# %%
data['TYPE']=label_encoder.fit_transform(data['TYPE'])

# %%
data['LANES']=label_encoder.fit_transform(data['LANES'])

# %%
data['LOCATION']=label_encoder.fit_transform(data['LOCATION'])

# %%
data['LENGTH'] = data['LENGTH'].astype('int')

# %%
sns.boxplot(None,data['LENGTH'])

# %%
sns.boxplot(None,data['ERECTED'])

# %%
data['LENGTH']=label_encoder.fit_transform(data['LENGTH'])

# %%
data['ERECTED']=label_encoder.fit_transform(data['ERECTED'])

# %%
sns.boxplot(None,data['ERECTED'])

# %%
corr = data.corr()

# %%
corr
# Out:
#              RIVER  LOCATION   ERECTED   PURPOSE    LENGTH     LANES  \
# RIVER     1.000000  0.369770  0.261741  0.140688  0.342026  0.041971
# LOCATION  0.369770  1.000000  0.115377  0.083249  0.295323 -0.066351
# ERECTED   0.261741  0.115377  1.000000 -0.089683  0.192901  0.648140
# PURPOSE   0.140688  0.083249 -0.089683  1.000000  0.215202 -0.150266
# LENGTH    0.342026  0.295323  0.192901  0.215202  1.000000 -0.106883
# LANES     0.041971 -0.066351  0.648140 -0.150266 -0.106883  1.000000
# CLEAR-G  -0.253686 -0.060991 -0.471909 -0.265488 -0.109312 -0.277194
# T-OR-D    0.171802 -0.027303 -0.372661  0.060782 -0.399111 -0.206334
# MATERIAL -0.150515 -0.013289 -0.241340 -0.146627 -0.159311 -0.055969
# SPAN     -0.554666 -0.352956 -0.552728 -0.103089 -0.371283 -0.338796
# REL-L    -0.246072 -0.231498 -0.125354  0.002715 -0.310914 -0.143865
# TYPE     -0.401553 -0.180763 -0.654235  0.041199 -0.254482 -0.500249
#
#            CLEAR-G    T-OR-D  MATERIAL      SPAN     REL-L      TYPE
# ...

# %%
corr.iloc[:,-1]
# Out:
# RIVER      -0.401553
# LOCATION   -0.180763
# ERECTED    -0.654235
# PURPOSE     0.041199
# LENGTH     -0.254482
# LANES      -0.500249
# CLEAR-G     0.413028
# T-OR-D      0.233444
# MATERIAL    0.380568
# SPAN        0.514372
# REL-L       0.342475
# TYPE        1.000000
# Name: TYPE, dtype: float64

# %%
sns.heatmap(corr)

# %%
data['LENGTH/SPAN'] = data['LENGTH'] + data['SPAN']

# %%
data['LOCATION/ERECTED'] = data['ERECTED'] + data['LOCATION']

# %%
data
# Out:
#     IDENTIF  RIVER  LOCATION  ERECTED  PURPOSE  LENGTH  LANES  CLEAR-G  \
# 1        E2      0        13        0        1      13      1        1
# 3        E5      0        17        1        1      10      1        1
# 5        E7      0        15        2        1       9      1        1
# 6        E8      0        16        3        0      10      0        1
# 7        E9      1        18        4        1      27      1        1
# ..      ...    ...       ...      ...      ...     ...    ...      ...
# 100     E86      0        22       46        1       8      2        0
# 101     E85      1        45       47        1      40      2        0
# 102     E84      0        12       48        1       2      3        0
# 103     E91      2        36       49        1      51      3        0
# 104     E90      1        43       50        1       6      3        0
#
#      T-OR-D  MATERIAL  SPAN  REL-L  TYPE  LENGTH/SPAN  LOCATION/ERECTED
# ...
